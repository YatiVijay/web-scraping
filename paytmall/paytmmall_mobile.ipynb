# %%
# !pip install selenium

# %%
# !apt-get update

# %%
# !apt install chromium-chromedriver

# %%
import selenium
from selenium import webdriver as wb
from selenium.webdriver.support.ui import Select
from selenium.webdriver import ActionChains
import pandas as pd
import time

# %%
options = wb.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# %%
site='https://paytmmall.com/shop/search?q=mobiles&from=organic&child_site_id=6&site_id=2&category=6224&page=1'

# %% [markdown]
# #mobile

# %%
links=[]
for j in range(1,29):
  site='https://paytmmall.com/shop/search?q=mobiles&from=organic&child_site_id=6&site_id=2&category=6224&page='+str(j)+''
  wd = wb.Chrome('chromedriver',options=options)
  wd.get(site)
  for i in range(1,9):
    for k in range(1,5):
      try:
        l=wd.find_element_by_xpath('//*[@id="app"]/div/div[3]/div/div/div[3]/div[2]/div['+str(i)+']/div['+str(k)+']/div/a').get_property('href')
        links.append(l)
      except:
        pass

# %%
print(len(links))
# Out:
# 64

# %%
prod_name=[]
star=[]
rating=[]
offer_price=[]
MRP=[]
discount=[]
cashback=[]
promocode=[]
cashback_more=[]
product_code=[]
model_id=[]
warranty=[]
seller_name=[]

for i in links:
  wdItem = wb.Chrome('chromedriver',options=options)
  wdItem.get(i)
  try:
    n=wdItem.find_element_by_class_name('NZJI').text
    prod_name.append(n)
  except:
    prod_name.append('Null')
  try:
    op=wdItem.find_element_by_class_name('_1V3w').text
    offer_price.append(op)
  except:
    offer_price.append('Null')
  try:
    mrp=wdItem.find_element_by_class_name('_2b_6').text.split(' ')[1]
    MRP.append(mrp)
  except:
    MRP.append('Null')
  try:
    d=wdItem.find_element_by_class_name('_3llF').text.split('-')[1]
    discount.append(d)
  except:
    discount.append('Null')
  try:
    s=wdItem.find_element_by_class_name('_2dWu').text
    star.append(s)
  except:
    star.append('Null')
  try:
    r=wdItem.find_element_by_class_name('_38Tb').text
    rating.append(r)
  except:
    rating.append('Null')
  try:
    c=wdItem.find_element_by_class_name('_2csj').text.split('₹')[1]
    cashback.append(c)
  except:
    cashback.append('Null')
  try:
    p=wdItem.find_element_by_class_name('PF1t').find_element_by_tag_name('strong').text
    promocode.append(p)
  except:
    promocode.append('Null')
  try:
    cm=wdItem.find_elements_by_class_name('_12vo')[0].text
    cashback_more.append(cm)
  except:
    cashback_more.append('Null')
  try:
    pc=wdItem.find_element_by_class_name('_1CXW').text.split('Product Code\n')[1].split('\n')[0]
    product_code.append(pc)
  except:
    product_code.append('Null')
  try:
    mid=wdItem.find_element_by_class_name('_1CXW').text.split('Model ID\n')[1].split('\n')[0]
    model_id.append(mid)
  except:
    model_id.append('Null')
  try:
    w=wdItem.find_elements_by_class_name('_3gQu')[0].text.split('\n')[1]
    if 'Select' in w:
      w='1 year manufacturer warranty for phone and 6 months for in the box accessories'
  except:
    try:
      w=wdItem.find_elements_by_class_name('nBgT')[0].text.split('\n')[1]
    except:
      w='Null'
  warranty.append(w)
  try:
    sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div[2]/div[2]')[0].text
  except:
    try:
      sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div/div')[0].text
      #//*[@id="app"]/div/div[3]/div/div[2]/div/div[2]/div[2]/div[2]/div[3]/div/div[2]/span
    except:
      sn='Null'
  seller_name.append(sn)

# %%
df={
  'category_link':['https://paytmmall.com/shop/search?q=mobiles&from=organic&child_site_id=6&site_id=2&category=6224']*len(links),
  'prod_link':links,
  'prod_name':prod_name,
  'stars':star,
  'ratings_reviews':rating,
  'offer_price':offer_price,
  'prod_mrp':MRP,
  'discount':discount,
  'currency':['INR']*len(offer_price),
  'cashback':cashback,
  'promocode':promocode,
  'cashback_more':cashback_more,
  'product_code':product_code,
  'model_id':model_id,
  'warranty':warranty,
  'seller_name':seller_name
}

# %%
dataset=pd.DataFrame(df)
dataset.head(20)

# %%
import csv
dataset.to_csv('mobile_paytmall.csv')

# %% [markdown]
# #laptop

# %%
links=[]
for j in range(1,8):
  site='https://paytmmall.com/shop/search?q=laptops&from=organic&child_site_id=6&site_id=2&category=6453&oq=laptop&page='+str(j)+''
  wd = wb.Chrome('chromedriver',options=options)
  wd.get(site)
  for i in range(1,9):
    for k in range(1,5):
      try:
        l=wd.find_element_by_xpath('//*[@id="app"]/div/div[3]/div/div/div[3]/div[2]/div['+str(i)+']/div['+str(k)+']/div/a').get_property('href')
        links.append(l)
      except:
        pass

# %%
print(len(links))
# Out:
# 61

# %%
for i in links:
  print(i)

# %%
prod_name=[]
star=[]
rating=[]
offer_price=[]
MRP=[]
discount=[]
cashback=[]
promocode=[]
cashback_more=[]
product_code=[]
model_id=[]
warranty=[]
seller_name=[]

for i in links:
  wdItem = wb.Chrome('chromedriver',options=options)
  wdItem.get(i)
  try:
    n=wdItem.find_element_by_class_name('NZJI').text
    prod_name.append(n)
  except:
    prod_name.append('Null')
  try:
    op=wdItem.find_element_by_class_name('_1V3w').text
    offer_price.append(op)
  except:
    offer_price.append('Null')
  try:
    mrp=wdItem.find_element_by_class_name('_2b_6').text.split(' ')[1]
    MRP.append(mrp)
  except:
    MRP.append('Null')
  try:
    d=wdItem.find_element_by_class_name('_3llF').text.split('-')[1]
    discount.append(d)
  except:
    discount.append('Null')
  try:
    s=wdItem.find_element_by_class_name('_2dWu').text
    star.append(s)
  except:
    star.append('Null')
  try:
    r=wdItem.find_element_by_class_name('_38Tb').text
    rating.append(r)
  except:
    rating.append('Null')
  try:
    c=wdItem.find_element_by_class_name('_2csj').text.split('₹')[1]
    cashback.append(c)
  except:
    cashback.append('Null')
  try:
    p=wdItem.find_element_by_class_name('PF1t').find_element_by_tag_name('strong').text
    promocode.append(p)
  except:
    promocode.append('Null')
  try:
    cm=wdItem.find_elements_by_class_name('_12vo')[0].text
    cashback_more.append(cm)
  except:
    cashback_more.append('Null')
  try:
    pc=wdItem.find_element_by_class_name('_1CXW').text.split('Product Code\n')[1].split('\n')[0]
    product_code.append(pc)
  except:
    product_code.append('Null')
  try:
    mid=wdItem.find_element_by_class_name('_1CXW').text.split('Model ID\n')[1].split('\n')[0]
    model_id.append(mid)
  except:
    model_id.append('Null')
  try:
    w=wdItem.find_elements_by_class_name('_3gQu')[0].text.split('\n')[1]
    if 'Select' in w:
      w='1 year manufacturer warranty for phone and 6 months for in the box accessories'
  except:
    try:
      w=wdItem.find_elements_by_class_name('nBgT')[0].text.split('\n')[1]
    except:
      w='Null'
  warranty.append(w)
  try:
    sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div[2]/div[2]')[0].text
  except:
    try:
      sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div/div')[0].text
      #//*[@id="app"]/div/div[3]/div/div[2]/div/div[2]/div[2]/div[2]/div[3]/div/div[2]/span
    except:
      sn='Null'
  seller_name.append(sn)

# %%
df={
  'category_link':['https://paytmmall.com/shop/search?q=laptops&from=organic&child_site_id=6&site_id=2&category=6453&oq=laptop']*len(links),
  'prod_link':links,
  'prod_name':prod_name,
  'stars':star,
  'ratings_reviews':rating,
  'offer_price':offer_price,
  'prod_mrp':MRP,
  'discount':discount,
  'currency':['INR']*len(offer_price),
  'cashback':cashback,
  'promocode':promocode,
  'cashback_more':cashback_more,
  'product_code':product_code,
  'model_id':model_id,
  'warranty':warranty,
  'seller_name':seller_name
}

# %%
dataset=pd.DataFrame(df)
dataset.head(20)
# Out:
#                                         category_link  ...         seller_name
# 0   https://paytmmall.com/shop/search?q=laptops&fr...  ...        Gadget Freak
# 1   https://paytmmall.com/shop/search?q=laptops&fr...  ...       Unbox Therapy
# 2   https://paytmmall.com/shop/search?q=laptops&fr...  ...       Unbox Therapy
# 3   https://paytmmall.com/shop/search?q=laptops&fr...  ...       Unbox Therapy
# 4   https://paytmmall.com/shop/search?q=laptops&fr...  ...       Unbox Therapy
# 5   https://paytmmall.com/shop/search?q=laptops&fr...  ...   Mobile Galaxy SLP
# 6   https://paytmmall.com/shop/search?q=laptops&fr...  ...         Home Expert
# 7   https://paytmmall.com/shop/search?q=laptops&fr...  ...        Joshidigital
# 8   https://paytmmall.com/shop/search?q=laptops&fr...  ...         IT Products
# 9   https://paytmmall.com/shop/search?q=laptops&fr...  ...         Sun Systems
# 10  https://paytmmall.com/shop/search?q=laptops&fr...  ...          Super Mall
# ...

# %%
import csv
dataset.to_csv('laptop_paytmall.csv')

# %% [markdown]
# #television

# %%
links=[]
for j in range(1,11):
  site='https://paytmmall.com/shop/search?q=tv&from=organic&child_site_id=6&site_id=2&category=24843&page='+str(j)+''
  wd = wb.Chrome('chromedriver',options=options)
  wd.get(site)
  for i in range(1,9):
    for k in range(1,5):
      try:
        l=wd.find_element_by_xpath('//*[@id="app"]/div/div[3]/div/div/div[3]/div[2]/div['+str(i)+']/div['+str(k)+']/div/a').get_property('href')
        links.append(l)
      except:
        pass

# %%
print(len(links))
# Out:
# 61

# %%
prod_name=[]
star=[]
rating=[]
offer_price=[]
MRP=[]
discount=[]
cashback=[]
promocode=[]
cashback_more=[]
product_code=[]
model_id=[]
warranty=[]
seller_name=[]

for i in links:
  wdItem = wb.Chrome('chromedriver',options=options)
  wdItem.get(i)
  try:
    n=wdItem.find_element_by_class_name('NZJI').text
    prod_name.append(n)
  except:
    prod_name.append('Null')
  try:
    op=wdItem.find_element_by_class_name('_1V3w').text
    offer_price.append(op)
  except:
    offer_price.append('Null')
  try:
    mrp=wdItem.find_element_by_class_name('_2b_6').text.split(' ')[1]
    MRP.append(mrp)
  except:
    MRP.append('Null')
  try:
    d=wdItem.find_element_by_class_name('_3llF').text.split('-')[1]
    discount.append(d)
  except:
    discount.append('Null')
  try:
    s=wdItem.find_element_by_class_name('_2dWu').text
    star.append(s)
  except:
    star.append('Null')
  try:
    r=wdItem.find_element_by_class_name('_38Tb').text
    rating.append(r)
  except:
    rating.append('Null')
  try:
    c=wdItem.find_element_by_class_name('_2csj').text.split('₹')[1]
    cashback.append(c)
  except:
    cashback.append('Null')
  try:
    p=wdItem.find_element_by_class_name('PF1t').find_element_by_tag_name('strong').text
    promocode.append(p)
  except:
    promocode.append('Null')
  try:
    cm=wdItem.find_elements_by_class_name('_12vo')[0].text
    cashback_more.append(cm)
  except:
    cashback_more.append('Null')
  try:
    pc=wdItem.find_element_by_class_name('_1CXW').text.split('Product Code\n')[1].split('\n')[0]
    product_code.append(pc)
  except:
    product_code.append('Null')
  try:
    mid=wdItem.find_element_by_class_name('_1CXW').text.split('Model ID\n')[1].split('\n')[0]
    model_id.append(mid)
  except:
    model_id.append('Null')
  try:
    w=wdItem.find_elements_by_class_name('_3gQu')[0].text.split('\n')[1]
    if 'Select' in w:
      w='1 year manufacturer warranty for phone and 6 months for in the box accessories'
  except:
    try:
      w=wdItem.find_elements_by_class_name('nBgT')[0].text.split('\n')[1]
    except:
      w='Null'
  warranty.append(w)
  try:
    sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div[2]/div[2]')[0].text
  except:
    try:
      sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div/div')[0].text
    except:
      sn='Null'
  seller_name.append(sn)

# %%
df={
  'category_link':['https://paytmmall.com/shop/search?q=tv&from=organic&child_site_id=6&site_id=2&category=24843']*len(links),
  'prod_link':links,
  'prod_name':prod_name,
  'stars':star,
  'ratings_reviews':rating,
  'offer_price':offer_price,
  'prod_mrp':MRP,
  'discount':discount,
  'currency':['INR']*len(offer_price),
  'cashback':cashback,
  'promocode':promocode,
  'cashback_more':cashback_more,
  'product_code':product_code,
  'model_id':model_id,
  'warranty':warranty,
  'seller_name':seller_name
}

# %%
dataset=pd.DataFrame(df)
dataset.head(20)

# %%
import csv
dataset.to_csv('television_paytmall.csv')

# %% [markdown]
# #speaker

# %%
links=[]
for j in range(1,36):
  site='https://paytmmall.com/shop/search?q=speaker&from=organic&child_site_id=6&site_id=2&category=11420%2C6455&page='+str(j)+''
  wd = wb.Chrome('chromedriver',options=options)
  wd.get(site)
  for i in range(1,9):
    for k in range(1,5):
      try:
        l=wd.find_element_by_xpath('//*[@id="app"]/div/div[3]/div/div/div[3]/div[2]/div['+str(i)+']/div['+str(k)+']/div/a').get_property('href')
        links.append(l)
      except:
        pass

# %%
print(len(links))
# Out:
# 62

# %%
prod_name=[]
star=[]
rating=[]
offer_price=[]
MRP=[]
discount=[]
cashback=[]
promocode=[]
cashback_more=[]
product_code=[]
model_id=[]
warranty=[]
seller_name=[]

for i in links:
  wdItem = wb.Chrome('chromedriver',options=options)
  wdItem.get(i)
  try:
    n=wdItem.find_element_by_class_name('NZJI').text
    prod_name.append(n)
  except:
    prod_name.append('Null')
  try:
    op=wdItem.find_element_by_class_name('_1V3w').text
    offer_price.append(op)
  except:
    offer_price.append('Null')
  try:
    mrp=wdItem.find_element_by_class_name('_2b_6').text.split(' ')[1]
    MRP.append(mrp)
  except:
    MRP.append('Null')
  try:
    d=wdItem.find_element_by_class_name('_3llF').text.split('-')[1]
    discount.append(d)
  except:
    discount.append('Null')
  try:
    s=wdItem.find_element_by_class_name('_2dWu').text
    star.append(s)
  except:
    star.append('Null')
  try:
    r=wdItem.find_element_by_class_name('_38Tb').text
    rating.append(r)
  except:
    rating.append('Null')
  try:
    c=wdItem.find_element_by_class_name('_2csj').text.split('₹')[1]
    cashback.append(c)
  except:
    cashback.append('Null')
  try:
    p=wdItem.find_element_by_class_name('PF1t').find_element_by_tag_name('strong').text
    promocode.append(p)
  except:
    promocode.append('Null')
  try:
    cm=wdItem.find_elements_by_class_name('_12vo')[0].text
    cashback_more.append(cm)
  except:
    cashback_more.append('Null')
  try:
    pc=wdItem.find_element_by_class_name('_1CXW').text.split('Product Code\n')[1].split('\n')[0]
    product_code.append(pc)
  except:
    product_code.append('Null')
  try:
    mid=wdItem.find_element_by_class_name('_1CXW').text.split('Model ID\n')[1].split('\n')[0]
    model_id.append(mid)
  except:
    model_id.append('Null')
  try:
    w=wdItem.find_elements_by_class_name('_3gQu')[0].text.split('\n')[1]
    if 'Select' in w:
      w='1 year manufacturer warranty for phone and 6 months for in the box accessories'
  except:
    try:
      w=wdItem.find_elements_by_class_name('nBgT')[0].text.split('\n')[1]
    except:
      w='Null'
  warranty.append(w)
  try:
    sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div[2]/div[2]')[0].text
  except:
    try:
      sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div/div')[0].text
    except:
      sn='Null'
  seller_name.append(sn)

# %%
df={
  'category_link':['https://paytmmall.com/shop/search?q=speaker&from=organic&child_site_id=6&site_id=2&category=11420%2C6455']*len(links),
  'prod_link':links,
  'prod_name':prod_name,
  'stars':star,
  'ratings_reviews':rating,
  'offer_price':offer_price,
  'prod_mrp':MRP,
  'discount':discount,
  'currency':['INR']*len(offer_price),
  'cashback':cashback,
  'promocode':promocode,
  'cashback_more':cashback_more,
  'product_code':product_code,
  'model_id':model_id,
  'warranty':warranty,
  'seller_name':seller_name
}

# %%
dataset=pd.DataFrame(df)
dataset.head(20)
# Out:
#                                         category_link  ...                           seller_name
# 0   https://paytmmall.com/shop/search?q=speaker&fr...  ...                              Pickadda
# 1   https://paytmmall.com/shop/search?q=speaker&fr...  ...                          E Planet SLP
# 2   https://paytmmall.com/shop/search?q=speaker&fr...  ...  MS TRADING COMPANY Authorised Seller
# 3   https://paytmmall.com/shop/search?q=speaker&fr...  ...             KONARRK Authorised Seller
# 4   https://paytmmall.com/shop/search?q=speaker&fr...  ...  PALCO SOUND SYSTEM Authorised Seller
# 5   https://paytmmall.com/shop/search?q=speaker&fr...  ...                   M S Trading Company
# 6   https://paytmmall.com/shop/search?q=speaker&fr...  ...                           Sun Systems
# 7   https://paytmmall.com/shop/search?q=speaker&fr...  ...                       Bayari Ventures
# 8   https://paytmmall.com/shop/search?q=speaker&fr...  ...                          Tarun Bharti
# ...

# %%
import csv
dataset.to_csv('speaker_paytmall.csv')

# %% [markdown]
# #camera

# %%
links=[]
for j in range(1,3):
  site='https://paytmmall.com/shop/search?q=cameras&from=organic&child_site_id=6&site_id=2&category=6373&oq=camera&page='+str(j)+''
  wd = wb.Chrome('chromedriver',options=options)
  wd.get(site)
  for i in range(1,9):
    for k in range(1,5):
      try:
        l=wd.find_element_by_xpath('//*[@id="app"]/div/div[3]/div/div/div[3]/div[2]/div['+str(i)+']/div['+str(k)+']/div/a').get_property('href')
        links.append(l)
      except:
        pass

# %%
print(len(links))
# Out:
# 44

# %%
prod_name=[]
star=[]
rating=[]
offer_price=[]
MRP=[]
discount=[]
cashback=[]
promocode=[]
cashback_more=[]
product_code=[]
model_id=[]
warranty=[]
seller_name=[]

for i in links:
  wdItem = wb.Chrome('chromedriver',options=options)
  wdItem.get(i)
  try:
    n=wdItem.find_element_by_class_name('NZJI').text
    prod_name.append(n)
  except:
    prod_name.append('Null')
  try:
    op=wdItem.find_element_by_class_name('_1V3w').text
    offer_price.append(op)
  except:
    offer_price.append('Null')
  try:
    mrp=wdItem.find_element_by_class_name('_2b_6').text.split(' ')[1]
    MRP.append(mrp)
  except:
    MRP.append('Null')
  try:
    d=wdItem.find_element_by_class_name('_3llF').text.split('-')[1]
    discount.append(d)
  except:
    discount.append('Null')
  try:
    s=wdItem.find_element_by_class_name('_2dWu').text
    star.append(s)
  except:
    star.append('Null')
  try:
    r=wdItem.find_element_by_class_name('_38Tb').text
    rating.append(r)
  except:
    rating.append('Null')
  try:
    c=wdItem.find_element_by_class_name('_2csj').text.split('₹')[1]
    cashback.append(c)
  except:
    cashback.append('Null')
  try:
    p=wdItem.find_element_by_class_name('PF1t').find_element_by_tag_name('strong').text
    promocode.append(p)
  except:
    promocode.append('Null')
  try:
    cm=wdItem.find_elements_by_class_name('_12vo')[0].text
    cashback_more.append(cm)
  except:
    cashback_more.append('Null')
  try:
    pc=wdItem.find_element_by_class_name('_1CXW').text.split('Product Code\n')[1].split('\n')[0]
    product_code.append(pc)
  except:
    product_code.append('Null')
  try:
    mid=wdItem.find_element_by_class_name('_1CXW').text.split('Model ID\n')[1].split('\n')[0]
    model_id.append(mid)
  except:
    model_id.append('Null')
  try:
    w=wdItem.find_elements_by_class_name('_3gQu')[0].text.split('\n')[1]
    if 'Select' in w:
      w='1 year manufacturer warranty for phone and 6 months for in the box accessories'
  except:
    try:
      w=wdItem.find_elements_by_class_name('nBgT')[0].text.split('\n')[1]
    except:
      w='Null'
  warranty.append(w)
  try:
    sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div[2]/div[2]')[0].text
  except:
    try:
      sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div/div')[0].text
    except:
      sn='Null'
  seller_name.append(sn)

# %%
df={
  'category_link':['https://paytmmall.com/shop/search?q=cameras&from=organic&child_site_id=6&site_id=2&category=6373&oq=camera']*len(links),
  'prod_link':links,
  'prod_name':prod_name,
  'stars':star,
  'ratings_reviews':rating,
  'offer_price':offer_price,
  'prod_mrp':MRP,
  'discount':discount,
  'currency':['INR']*len(offer_price),
  'cashback':cashback,
  'promocode':promocode,
  'cashback_more':cashback_more,
  'product_code':product_code,
  'model_id':model_id,
  'warranty':warranty,
  'seller_name':seller_name
}

# %%
dataset=pd.DataFrame(df)
dataset.head(20)
# Out:
#                                         category_link  ...                    seller_name
# 0   https://paytmmall.com/shop/search?q=cameras&fr...  ...                         A1 Lab
# 1   https://paytmmall.com/shop/search?q=cameras&fr...  ...         Best Deal Camera Point
# 2   https://paytmmall.com/shop/search?q=cameras&fr...  ...                  Camera Stores
# 3   https://paytmmall.com/shop/search?q=cameras&fr...  ...                    Krazy Deals
# 4   https://paytmmall.com/shop/search?q=cameras&fr...  ...         Best Deal Camera Point
# 5   https://paytmmall.com/shop/search?q=cameras&fr...  ...                         A1 Lab
# 6   https://paytmmall.com/shop/search?q=cameras&fr...  ...         Best Deal Camera Point
# 7   https://paytmmall.com/shop/search?q=cameras&fr...  ...         Best Deal Camera Point
# 8   https://paytmmall.com/shop/search?q=cameras&fr...  ...         Best Deal Camera Point
# ...

# %%
import csv
dataset.to_csv('camera_paytmall.csv')

# %% [markdown]
# #washing machine

# %%
links=[]
for j in range(1,6):
  site='https://paytmmall.com/shop/search?q=washing%20machinr&from=organic&child_site_id=6&site_id=2&category=24836&page='+str(j)+''
  wd = wb.Chrome('chromedriver',options=options)
  wd.get(site)
  for i in range(1,9):
    for k in range(1,5):
      try:
        l=wd.find_element_by_xpath('//*[@id="app"]/div/div[3]/div/div/div[3]/div[2]/div['+str(i)+']/div['+str(k)+']/div/a').get_property('href')
        links.append(l)
      except:
        pass

# %%
print(len(links))
# Out:
# 61

# %%
prod_name=[]
star=[]
rating=[]
offer_price=[]
MRP=[]
discount=[]
cashback=[]
promocode=[]
cashback_more=[]
product_code=[]
model_id=[]
warranty=[]
seller_name=[]

for i in links:
  wdItem = wb.Chrome('chromedriver',options=options)
  wdItem.get(i)
  try:
    n=wdItem.find_element_by_class_name('NZJI').text
    prod_name.append(n)
  except:
    prod_name.append('Null')
  try:
    op=wdItem.find_element_by_class_name('_1V3w').text
    offer_price.append(op)
  except:
    offer_price.append('Null')
  try:
    mrp=wdItem.find_element_by_class_name('_2b_6').text.split(' ')[1]
    MRP.append(mrp)
  except:
    MRP.append('Null')
  try:
    d=wdItem.find_element_by_class_name('_3llF').text.split('-')[1]
    discount.append(d)
  except:
    discount.append('Null')
  try:
    s=wdItem.find_element_by_class_name('_2dWu').text
    star.append(s)
  except:
    star.append('Null')
  try:
    r=wdItem.find_element_by_class_name('_38Tb').text
    rating.append(r)
  except:
    rating.append('Null')
  try:
    c=wdItem.find_element_by_class_name('_2csj').text.split('₹')[1]
    cashback.append(c)
  except:
    cashback.append('Null')
  try:
    p=wdItem.find_element_by_class_name('PF1t').find_element_by_tag_name('strong').text
    promocode.append(p)
  except:
    promocode.append('Null')
  try:
    cm=wdItem.find_elements_by_class_name('_12vo')[0].text
    cashback_more.append(cm)
  except:
    cashback_more.append('Null')
  try:
    pc=wdItem.find_element_by_class_name('_1CXW').text.split('Product Code\n')[1].split('\n')[0]
    product_code.append(pc)
  except:
    product_code.append('Null')
  try:
    mid=wdItem.find_element_by_class_name('_1CXW').text.split('Model ID\n')[1].split('\n')[0]
    model_id.append(mid)
  except:
    model_id.append('Null')
  try:
    w=wdItem.find_elements_by_class_name('_3gQu')[0].text.split('\n')[1]
    if 'Select' in w:
      w='1 year manufacturer warranty for phone and 6 months for in the box accessories'
  except:
    try:
      w=wdItem.find_elements_by_class_name('nBgT')[0].text.split('\n')[1]
    except:
      w='Null'
  warranty.append(w)
  try:
    sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div[2]/div[2]')[0].text
  except:
    try:
      sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div/div')[0].text
    except:
      sn='Null'
  seller_name.append(sn)

# %%
df={
  'category_link':['https://paytmmall.com/shop/search?q=washing%20machinr&from=organic&child_site_id=6&site_id=2&category=24836']*len(links),
  'prod_link':links,
  'prod_name':prod_name,
  'stars':star,
  'ratings_reviews':rating,
  'offer_price':offer_price,
  'prod_mrp':MRP,
  'discount':discount,
  'currency':['INR']*len(offer_price),
  'cashback':cashback,
  'promocode':promocode,
  'cashback_more':cashback_more,
  'product_code':product_code,
  'model_id':model_id,
  'warranty':warranty,
  'seller_name':seller_name
}

# %%
dataset=pd.DataFrame(df)
dataset.head(20)
# Out:
#                                         category_link  ...               seller_name
# 0   https://paytmmall.com/shop/search?q=washing%20...  ...   Croma Authorised Seller
# 1   https://paytmmall.com/shop/search?q=washing%20...  ...              Noida Direct
# 2   https://paytmmall.com/shop/search?q=washing%20...  ...              Best Buy Sec
# 3   https://paytmmall.com/shop/search?q=washing%20...  ...  Hafele Authorised Seller
# 4   https://paytmmall.com/shop/search?q=washing%20...  ...  DVIZIO Authorised Seller
# 5   https://paytmmall.com/shop/search?q=washing%20...  ...      MR Surya Electronics
# 6   https://paytmmall.com/shop/search?q=washing%20...  ...              Only For You
# 7   https://paytmmall.com/shop/search?q=washing%20...  ...         Online Source Hub
# 8   https://paytmmall.com/shop/search?q=washing%20...  ...              Home Shopper
# 9   https://paytmmall.com/shop/search?q=washing%20...  ...              Home Shopper
# ...

# %%
import csv
dataset.to_csv('WashingMachine_paytmall.csv')

# %% [markdown]
# #microwave oven

# %%
links=[]
for j in range(1,5):
  site='https://paytmmall.com/shop/search?q=microwave%20oven&from=organic&child_site_id=6&site_id=2&page='+str(j)+'&category=24839'
  wd = wb.Chrome('chromedriver',options=options)
  wd.get(site)
  for i in range(1,9):
    for k in range(1,5):
      try:
        l=wd.find_element_by_xpath('//*[@id="app"]/div/div[3]/div/div/div[3]/div[2]/div['+str(i)+']/div['+str(k)+']/div/a').get_property('href')
        links.append(l)
      except:
        pass

# %%
print(len(links))
# Out:
# 61

# %%
prod_name=[]
star=[]
rating=[]
offer_price=[]
MRP=[]
discount=[]
cashback=[]
promocode=[]
cashback_more=[]
product_code=[]
model_id=[]
warranty=[]
seller_name=[]

for i in links:
  wdItem = wb.Chrome('chromedriver',options=options)
  wdItem.get(i)
  try:
    n=wdItem.find_element_by_class_name('NZJI').text
    prod_name.append(n)
  except:
    prod_name.append('Null')
  try:
    op=wdItem.find_element_by_class_name('_1V3w').text
    offer_price.append(op)
  except:
    offer_price.append('Null')
  try:
    mrp=wdItem.find_element_by_class_name('_2b_6').text.split(' ')[1]
    MRP.append(mrp)
  except:
    MRP.append('Null')
  try:
    d=wdItem.find_element_by_class_name('_3llF').text.split('-')[1]
    discount.append(d)
  except:
    discount.append('Null')
  try:
    s=wdItem.find_element_by_class_name('_2dWu').text
    star.append(s)
  except:
    star.append('Null')
  try:
    r=wdItem.find_element_by_class_name('_38Tb').text
    rating.append(r)
  except:
    rating.append('Null')
  try:
    c=wdItem.find_element_by_class_name('_2csj').text.split('₹')[1]
    cashback.append(c)
  except:
    cashback.append('Null')
  try:
    p=wdItem.find_element_by_class_name('PF1t').find_element_by_tag_name('strong').text
    promocode.append(p)
  except:
    promocode.append('Null')
  try:
    cm=wdItem.find_elements_by_class_name('_12vo')[0].text
    cashback_more.append(cm)
  except:
    cashback_more.append('Null')
  try:
    pc=wdItem.find_element_by_class_name('_1CXW').text.split('Product Code\n')[1].split('\n')[0]
    product_code.append(pc)
  except:
    product_code.append('Null')
  try:
    mid=wdItem.find_element_by_class_name('_1CXW').text.split('Model ID\n')[1].split('\n')[0]
    model_id.append(mid)
  except:
    model_id.append('Null')
  try:
    w=wdItem.find_elements_by_class_name('_3gQu')[0].text.split('\n')[1]
    if 'Select' in w:
      w='1 year manufacturer warranty for phone and 6 months for in the box accessories'
  except:
    try:
      w=wdItem.find_elements_by_class_name('nBgT')[0].text.split('\n')[1]
    except:
      w='Null'
  warranty.append(w)
  try:
    sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div[2]/div[2]')[0].text
  except:
    try:
      sn=wdItem.find_elements_by_xpath('//*[@id="app"]/div/div[3]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[1]/div[2]/div/div')[0].text
    except:
      sn='Null'
  seller_name.append(sn)

# %%
df={
  'category_link':['https://paytmmall.com/shop/search?q=microwave%20oven&from=organic&child_site_id=6&site_id=2']*len(links),
  'prod_link':links,
  'prod_name':prod_name,
  'stars':star,
  'ratings_reviews':rating,
  'offer_price':offer_price,
  'prod_mrp':MRP,
  'discount':discount,
  'currency':['INR']*len(offer_price),
  'cashback':cashback,
  'promocode':promocode,
  'cashback_more':cashback_more,
  'product_code':product_code,
  'model_id':model_id,
  'warranty':warranty,
  'seller_name':seller_name
}

# %%
dataset=pd.DataFrame(df)
dataset.head(20)
# Out:
#                                         category_link  ...             seller_name
# 0   https://paytmmall.com/shop/search?q=microwave%...  ...                  Amerex
# 1   https://paytmmall.com/shop/search?q=microwave%...  ...       Sahil Electronics
# 2   https://paytmmall.com/shop/search?q=microwave%...  ...      Monika Electronics
# 3   https://paytmmall.com/shop/search?q=microwave%...  ...           Unboxed Deals
# 4   https://paytmmall.com/shop/search?q=microwave%...  ...  Orbit Electro Domestic
# 5   https://paytmmall.com/shop/search?q=microwave%...  ...         S S Electronics
# 6   https://paytmmall.com/shop/search?q=microwave%...  ...       Online Source Hub
# 7   https://paytmmall.com/shop/search?q=microwave%...  ...   T T K Prestige E Shop
# 8   https://paytmmall.com/shop/search?q=microwave%...  ...                 Uni One
# 9   https://paytmmall.com/shop/search?q=microwave%...  ...   New YBM Incorporation
# ...

# %%
import csv
dataset.to_csv('MicrowaveOven_paytmall.csv')

# %% [markdown]
# ## mobile, laptop, speaker, camera, television, washing machine, microwave oven

# %% [markdown]
# #trial

# %%
wdItem = wb.Chrome('chromedriver',options=options)
wdItem.get(links[4])

# %%
p=wdItem.find_element_by_class_name('PF1t').find_element_by_tag_name('strong').text
#w=wdItem.find_elements_by_class_name('nBgT')[0].text.split('\n')[1]
#r=wdItem.find_element_by_class_name('_38Tb').text
print(p)
# Out:
# MALLBONANZA

# %%
print(links[4])
# Out:
# https://paytmmall.com/orbit-12litr-corvus-otg-oven-white-oven-toaster-grill-CMPLXLARORBIT-12LITRORBI41326418948FC-pdp?product_id=204740941&sid=052d0153-f6a9-4e65-8d3e-1cc475611bdb&src=consumer_search&svc=-1&cid=24839&tracker=organic%7C24839%7Cmicrowave%20oven%7Cgrid%7CSearch_experimentName%3Ddemographics_location%23NA%7C%7C6%7Cdemographics_location%23NA&get_review_id=204740943&site_id=2&child_site_id=6

# %%
links=[]
site='https://paytmmall.com/shop/search?q=mobiles&from=organic&child_site_id=6&site_id=2&category=6224&page='+str(25)+''
wd = wb.Chrome('chromedriver',options=options)
wd.get(site)
for i in range(1,9):
  for k in range(1,5):
    try:
      l=wd.find_element_by_xpath('//*[@id="app"]/div/div[3]/div/div/div[3]/div[2]/div['+str(i)+']/div['+str(k)+']/div/a').get_property('href')
      links.append(l)
    except:
      pass

# %%
print(len(links))
# Out:
# 31

# %%
print(links[30])
# Out:
# https://paytmmall.com/vivo-y20g-6-gb-128-gb-purist-blue-CMPLXMOBVIVO-Y20G-6-KIAA2228024D0BF6CD-pdp?product_id=335085042&sid=6890709a-6343-4773-839b-a8bf6cc479a9&src=consumer_search&svc=-1&cid=66781&tracker=organic%7C6224%7Cmobiles%7Cgrid%7CSearch_experimentName%3Ddemographics_location%23NA%7C%7C32%7Cdemographics_location%23NA&get_review_id=335085045&site_id=2&child_site_id=6
